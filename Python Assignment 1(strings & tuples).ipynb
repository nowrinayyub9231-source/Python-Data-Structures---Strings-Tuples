# %% [markdown]
# #### STRING CONCATENATION -- --

# %%
name="Nowrin"
print("Hello",name)
py=", Welcome to python programming"
print("Hello",name,py)
# Out:
# Hello Nowrin
# Hello Nowrin , Welcome to python programming

# %% [markdown]
# #### STRING SLICING AND INDEXING --

# %%
text="Hello Nowrin , Welcome to python programming"
text[0]
# Out:
# 'H'

# %%
text[-1]
# Out:
# 'g'

# %%
text[:5]
# Out:
# 'Hello'

# %%
text[-11:]
# Out:
# 'programming'

# %%
text[::-1]
# Out:
# 'gnimmargorp nohtyp ot emocleW , nirwoN olleH'

# %%
text.index('python')
print(text[26:32])
# Out:
# python

# %% [markdown]
# #### STRING METHODS --

# %%
strM="python beginner tutorial"

# %%
strM.upper()
# Out:
# 'PYTHON BEGINNER TUTORIAL'

# %%
strM.lower()
# Out:
# 'python beginner tutorial'

# %%
strM.capitalize()
# Out:
# 'Python beginner tutorial'

# %%
strM.count('t')
# Out:
# 3

# %%
strM.replace("python","Machine learning")
# Out:
# 'Machine learning beginner tutorial'

# %% [markdown]
# #### TUPLES --

# %%
T1=(10,20,30)
T2=(40,50,60)
t_combine= T1+T2
print("t_combine","=",t_combine)
# Out:
# t_combine = (10, 20, 30, 40, 50, 60)

# %%
t_combine = (10, 20, 30, 40, 50, 60)
print(t_combine*3)
# Out:
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)

# %%
t_combine[2]
# Out:
# 30

# %%
print(t_combine[:3])
# Out:
# (10, 20, 30)

# %%
print(t_combine[-3:])
# Out:
# (40, 50, 60)
